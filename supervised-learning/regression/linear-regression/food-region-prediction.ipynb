# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Data Preparation

# %%
file = "/Users/ausin/Downloads/Food Waste data and research - by country.csv"
data = pd.read_csv(file)
data
# Out:
#                         Country  combined figures (kg/capita/year)  \
# 0                   Afghanistan                                126
# 1                       Albania                                127
# 2                       Algeria                                135
# 3                       Andorra                                123
# 4                        Angola                                144
# ..                          ...                                ...
# 209  Venezuela (Boliv. Rep. of)                                116
# 210                    Viet Nam                                120
# 211                       Yemen                                148
# 212                      Zambia                                122
# 213                    Zimbabwe                                144
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                     82                           3109153
# ...

# %%
import pandas as pd

df = pd.DataFrame({
    "roll-no": [1,2,3],
    "homework": ['submitted','not-submitted',np.nan]
})
df.notnull()
# Out:
#    roll-no  homework
# 0     True      True
# 1     True      True
# 2     True     False

# %%
data.head(20)
# Out:
#                 Country  combined figures (kg/capita/year)  \
# 0           Afghanistan                                126
# 1               Albania                                127
# 2               Algeria                                135
# 3               Andorra                                123
# 4                Angola                                144
# 5   Antigua and Barbuda                                113
# 6             Argentina                                116
# 7               Armenia                                137
# 8                 Aruba                                113
# 9             Australia                                133
# 10              Austria                                 76
# 11           Azerbaijan                                137
# 12              Bahamas                                113
# 13              Bahrain                                171
# 14           Bangladesh                                 84
# ...

# %%
data.tail(20)
# Out:
#                           Country  combined figures (kg/capita/year)  \
# 194                       Tunisia                                135
# 195                        Turkey                                137
# 196                  Turkmenistan                                120
# 197      Turks and Caicos Islands                                113
# 198                        Tuvalu                                120
# 199                        Uganda                                147
# 200                       Ukraine                                120
# 201          United Arab Emirates                                134
# 202                United Kingdom                                 98
# 203       United Rep. of Tanzania                                163
# 204      United States of America                                139
# 205  United States Virgin Islands                                113
# 206                       Uruguay                                113
# ...

# %%
data[['Country','Region']].tail(20)
# Out:
#                           Country                           Region
# 194                       Tunisia                  Northern Africa
# 195                        Turkey                     Western Asia
# 196                  Turkmenistan                     Central Asia
# 197      Turks and Caicos Islands  Latin America and the Caribbean
# 198                        Tuvalu                        Polynesia
# 199                        Uganda               Sub-Saharan Africa
# 200                       Ukraine                   Eastern Europe
# 201          United Arab Emirates                     Western Asia
# 202                United Kingdom                  Northern Europe
# 203       United Rep. of Tanzania               Sub-Saharan Africa
# 204      United States of America                 Northern America
# 205  United States Virgin Islands  Latin America and the Caribbean
# 206                       Uruguay  Latin America and the Caribbean
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 12 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Country                                 214 non-null    object
#  1   combined figures (kg/capita/year)       214 non-null    int64
#  2   Household estimate (kg/capita/year)     214 non-null    int64
#  3   Household estimate (tonnes/year)        214 non-null    int64
#  4   Retail estimate (kg/capita/year)        214 non-null    int64
#  5   Retail estimate (tonnes/year)           214 non-null    int64
#  6   Food service estimate (kg/capita/year)  214 non-null    int64
#  7   Food service estimate (tonnes/year)     214 non-null    int64
#  8   Confidence in estimate                  214 non-null    object
#  9   M49 code                                214 non-null    int64
# ...

# %%
data['Region'].describe()
# Out:
# count                    214
# unique                    17
# top       Sub-Saharan Africa
# freq                      48
# Name: Region, dtype: object

# %%
confidence = LabelEncoder()
region = LabelEncoder()

# %%
data['Confidence in estimate'] = confidence.fit_transform(data['Confidence in estimate'])
data['Region'] = region.fit_transform(data['Region'])

# %%
data.head()
# Out:
#        Country  combined figures (kg/capita/year)  \
# 0  Afghanistan                                126
# 1      Albania                                127
# 2      Algeria                                135
# 3      Andorra                                123
# 4       Angola                                144
#
#    Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                   82                           3109153
# 1                                   83                            238492
# 2                                   91                           3918529
# 3                                   84                              6497
# 4                                  100                           3169523
#
#    Retail estimate (kg/capita/year)  Retail estimate (tonnes/year)  \
# 0                                16                         594982
# 1                                16                          45058
# ...

# %%
features = ['Household estimate (kg/capita/year)', 'Retail estimate (kg/capita/year)', 
            'Food service estimate (kg/capita/year)', 'Confidence in estimate', 'Region']
target = 'combined figures (kg/capita/year)'

# %%
X = data[features]
y = data[target]

# %%
X
# Out:
#      Household estimate (kg/capita/year)  Retail estimate (kg/capita/year)  \
# 0                                     82                                16
# 1                                     83                                16
# 2                                     91                                16
# 3                                     84                                13
# 4                                    100                                16
# ..                                   ...                               ...
# 209                                   72                                16
# 210                                   76                                16
# 211                                  104                                16
# 212                                   78                                16
# 213                                  100                                16
#
# ...

# %%
y
# Out:
# 0      126
# 1      127
# 2      135
# 3      123
# 4      144
#       ...
# 209    116
# 210    120
# 211    148
# 212    122
# 213    144
# Name: combined figures (kg/capita/year), Length: 214, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=12)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (149, 5)
# (65, 5)
# (149,)
# (65,)

# %%
model = RandomForestRegressor(random_state=42)

# %%
model.fit(X_train, y_train)

# Predictions and Evaluation
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5

# Display the RMSE
print(f'Root Mean Squared Error (RMSE): {rmse}')
# Out:
# Root Mean Squared Error (RMSE): 7.870929766210304

# %%
y_pred
# Out:
# array([135.9 , 123.8 , 147.  , 144.  , 116.  , 139.77, 134.15, 113.  ,
#        136.79, 109.35, 144.  , 116.  , 130.1 , 122.43, 147.  , 136.79,
#        122.76, 185.04, 171.11, 101.12, 120.21, 145.29,  99.81, 122.15,
#        134.15, 132.6 , 126.72, 133.52, 115.  , 126.72, 123.8 , 116.68,
#        115.  , 111.44, 135.  , 118.01, 135.9 , 113.  , 113.  , 144.  ,
#        147.  , 147.  , 147.  , 116.  , 100.64, 117.96, 135.  , 119.96,
#        173.15, 126.72, 113.  , 144.  , 148.52, 120.09, 144.  , 103.15,
#        110.32, 172.41, 122.78, 113.  , 111.46, 101.77, 135.9 , 113.  ,
#        110.32])

# %%
X_test
# Out:
#      Household estimate (kg/capita/year)  Retail estimate (kg/capita/year)  \
# 131                                   92                                16
# 86                                    80                                16
# 177                                  103                                16
# 31                                   100                                16
# 209                                   72                                16
# ..                                   ...                               ...
# 125                                   72                                13
# 63                                    78                                 5
# 24                                    92                                16
# 8                                     74                                13
# 40                                    71                                13
#
# ...

# %%
y_test
# Out:
# 131    136
# 86     124
# 177    147
# 31     144
# 209    116
#       ...
# 125    111
# 63     100
# 24     136
# 8      113
# 40     110
# Name: combined figures (kg/capita/year), Length: 65, dtype: int64
